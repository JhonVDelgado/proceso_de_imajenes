# %%
import os
print(os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset"))
# Out:
# ['test', 'test.csv', 'train', 'train.csv', 'train1.csv', '__MACOSX']

# %%
import os
print(os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/train"))
import tensorflow as tf
import tensorflow_datasets as tfds
datos. metadatos = tdfs.load ("C:/Users/botnet/Downloads/Homework/CarneDataset/train", as_supervised=True, with_info=True)
metadatos
import matplotlib.pyplot as plt
for i, (image, etiqueta) in enumerate(data['train'].take(2)):
  plt.imshow(image)
# Out:
# ['.DS_Store', 'CLASS_01', 'CLASS_02', 'CLASS_03', 'CLASS_04', 'CLASS_05', 'CLASS_06', 'CLASS_07', 'CLASS_08']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       2 print(os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/train"))
#       3 import tensorflow as tf
# ----> 4 import tensorflow_datasets as tfds
#       5 datos. metadatos = tdfs.load ("C:/Users/botnet/Downloads/Homework/CarneDataset/train", as_supervised=True, with_info=True)
#       6 metadatos
#
# ModuleNotFoundError: No module named 'tensorflow_datasets'

# %%
from PIL import Image
import numpy as np

im = np.array(Image.open('C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png'))

im_R = im.copy()
im_R[:, :, (1, 2)] = 0
im_G = im.copy()
im_G[:, :, (0, 2)] = 0
im_B = im.copy()
im_B[:, :, (0, 1)] = 0

im_RGB = np.concatenate((im_R, im_G, im_B), axis=1)

pil_img = Image.fromarray(im_RGB)
pil_img.save('carneprocesada.jpg')

# %%
from PIL import Image
import numpy as np

im = np.array(Image.open('C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png'))

im_R = im.copy()
im_R[:, :, (1, 2)] = 0
im_G = im.copy()
im_G[:, :, (0, 2)] = 0
im_B = im.copy()
im_B[:, :, (0, 1)] = 0

im_RGB = np.concatenate((im_R, im_G, im_B), axis=1)

pil_img = Image.fromarray(im_RGB)
pil_img.save('Carneroja1.png')

# %%
from PIL import Image
import numpy as np

im = np.array(Image.open('C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png'))

im_R = im.copy()
im_R[:, :, (1, 2)] = 0
im_G = im.copy()
im_G[:, :, (0, 2)] = 0
im_B = im.copy()
im_B[:, :, (0, 1)] = 0

im_RGB = np.concatenate((im_R, im_G, im_B), axis=1)

pil_img = Image.fromarray(im_RGB)
pil_img.save('Carneroja1.png')

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
im = Image.open('C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png')
print(im.format)
print(im.size)
print(im.mode)
im

# %%
foto = Image.open('C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png')
foto
foto_gris = foto.convert('L')
foto_gris

# %%
image_directory = 'C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02';
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
#import im.img_qc as img_qc
# %matplotlib inline
# parameters for matplotlib to increase our default figure size -- NOTE: figure sizes are in INCHES
plt.rcParams["figure.figsize"] = (100,100) # set as needed for your screen and eyes
# on a high-dpi monitor this will increase the quality of plots on-screen
# %config InlineBackend.figure_format = 'retina'
# get image_paths for PNG images
image_paths = Path(image_directory).glob('*.png')
image_paths
# get image_paths list
image_paths_list = list(image_paths)
image_paths_list
# try to get sorted image_paths list
image_paths_list = sorted(image_paths)
image_paths_list
# get image_paths for TIFF images
image_paths = Path(image_directory).glob('*.png')
image_paths_list = sorted(image_paths)
image_paths_list
# open first image in our list
image = Image.open(image_paths_list[0]) # list slicing
# show image
plt.imshow(image)

# %%
from matplotlib.pyplot import subplot, imshow, title
from matplotlib.image import imread

# Importing the image
I = imread("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02/Carneroja.png");
subplot(2, 3, 1),
imshow(I);
title("Original image");

% Dilated Image

def strel(param, param1, param2):
    pass


se = strel("line", 7, 7);


def imdilate(I, se):
    pass


dilate = imdilate(I, se);
subplot(2, 3, 2),
imshow(dilate);
title("Dilated image");

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout
from keras.layers import Flatten, BatchNormalization
train_df = pd.read_csv('./C:/Users/botnet/Downloads/Homework/CarneDataset/train1.csv')
test_df = pd.read_csv('./C:/Users/botnet/Downloads/Homework/CarneDataset/test.csv')

train_df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In
# %%
from os import path
from pathlib import Path
from ipywidgets import Output, Button, Layout, HBox
from IPython.display import Image, display, clear_output
classes = ["pollo", "carne"]

# store path and search for .jpg images in path
#path = Path("./C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02")
images = [img.name for img in path.glob("*.png")]

# set up empty dict for labels and initial position
labels = {}
position = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 9>()
#       5 classes = ["pollo", "carne"]
#       7 # store path and search for .jpg images in path
#       8 #path = Path("./C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02")
# ----> 9 images = [img.name for img in path.glob("*.png")]
#      11 # set up empty dict for labels and initial position
#      12 labels = {}
#
# AttributeError: module 'ntpath' has no attribute 'glob'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
import glob
from skimage.io import imread
import mxnet as mx
import gluoncv as gcv
import matplotlib.pyplot as plt
import cv2(imread)
import os
# Out:
#   Input In [17]
#     import cv2(imread)
#               ^
# SyntaxError: invalid syntax

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,               # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        shuffle=True,
        class_mode='binary')

# Flow validation images in batches of 20 using val_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        shuffle=True,
        class_mode='binary' )

# %%
img_input = layers.Input(shape=(150, 150, 3))

# First convolution extracts 16 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(16, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# Second convolution extracts 32 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Third convolution extracts 64 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Flatten feature map to a 1-dim tensor so we can add fully connected layers
x = layers.Flatten()(x)

# Create a fully connected layer with ReLU activation and 512 hidden units
x = layers.Dense(512, activation='relu')(x)

# Add a dropout rate of 0.5
x = layers.Dropout(0.5)(x)

# Create output layer with a single node and sigmoid activation
output = layers.Dense(1, activation='sigmoid')(x)

# Create model:
# input = input feature map
# output = input feature map + stacked convolution/maxpooling layers + fully
# connected layer + sigmoid output layer
model = Model(img_input, output)

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and validation data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc, label='training accuracy')
plt.plot(epochs, val_acc, label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

# Plot training and validation loss per epoch
plt.figure()
plt.plot(epochs, loss, label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.title('Training and validation loss')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 acc = history.history['acc']
#       2 val_acc = history.history['val_acc']
#       4 # Retrieve a list of list results on training and validation data
#       5 # sets for each training epoch
#
# NameError: name 'history' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.data import Carneroja
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.morphology import label, closing, square
from skimage.measure import regionprops
from skimage.color import lab2rgb
# %matplotlib inline
def show(img, cmap=None):
    cmap = cmap or plt.cm.gray
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.imshow(img, cmap=cmap)
    ax.set_axis_off()
    plt.show()
img = Carneroja()
show(img)
threshold_otsu(img)
107
show(img > 107)
from ipywidgets import widgets

@widgets.interact(t=(50, 240))
def threshold(t):
    img_bin = clear_border(closing(img > 120, square(5)))
show(img_bin)
show(img > t)

labels = label(img_bin)
show(labels, cmap=plt.cm.rainbow)
regions = regionprops(labels)
boxes = np.array([label['BoundingBox']
                  for label in regions
                  if label['Area'] > 100])
print(f"There are {len(boxes)} Carneroja.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from skimage.data import Carneroja
#       4 from skimage.filters import threshold_otsu
#       5 from skimage.segmentation import clear_border
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\anaconda3\lib\site-packages\skimage\_shared\lazy.py:64, in attach.<locals>.__getattr__(name)
#      62     return importlib.import_module(f'{package_name}.{name}')
#      63 elif name in attr_to_modules:
# ---> 64     submod = importlib.import_module(
#      65         f'{package_name}.{attr_to_modules[name]}'
#      66     )
#      67     return getattr(submod, name)
#      68 else:
#
# File ~\anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\lib\site-packages\skimage\data\_fetchers.py:14, in <module>
#      12 from ..util.dtype import img_as_bool
#      13 from ._binary_blobs import binary_blobs
# ---> 14 from ._registry import registry, legacy_registry, registry_urls
#      16 from .. import __version__
#      18 import os.path as osp
#
# File ~\anaconda3\lib\site-packages\skimage\data\_registry.py:184, in <module>
#      44 registry = {
#      45     "color/tests/data/lab_array_a_10.npy": "a3ef76f1530e374f9121020f1f220bc89767dc866f4bbd1b1f47e5b84891a38c",
#      46     "color/tests/data/lab_array_a_2.npy": "793d5981cbffceb14b5fb589f998a2b1acdb5ff9c14d364c8e9e8bd45a80b275",
#    (...)
#     165     "data/solidification.tif": "50ef9a52c621b7c0c506ad1fe1b8ee8a158a4d7c8e50ddfce1e273a422dca3f9",
#     166 }
#     168 registry_urls = {
#     169     "data/brain.tiff": "https://gitlab.com/scikit-image/data/-/raw/master/brain.tiff",
#     170     "data/cells3d.tif": "https://gitlab.com/scikit-image/data/-/raw/master/cells3d.tif",
#    (...)
#     181     "restoration/tests/astronaut_rl.npy": "https://gitlab.com/scikit-image/data/-/raw/master/astronaut_rl.npy",
#     182 }
# --> 184 legacy_registry = {
#     185     ('data/' + filename): registry['data/' + filename]
#     186     for filename in legacy_datasets
#     187 }
#
# File ~\anaconda3\lib\site-packages\skimage\data\_registry.py:185, in <dictcomp>(.0)
#      44 registry = {
#      45     "color/tests/data/lab_array_a_10.npy": "a3ef76f1530e374f9121020f1f220bc89767dc866f4bbd1b1f47e5b84891a38c",
#      46     "color/tests/data/lab_array_a_2.npy": "793d5981cbffceb14b5fb589f998a2b1acdb5ff9c14d364c8e9e8bd45a80b275",
#    (...)
#     165     "data/solidification.tif": "50ef9a52c621b7c0c506ad1fe1b8ee8a158a4d7c8e50ddfce1e273a422dca3f9",
#     166 }
#     168 registry_urls = {
#     169     "data/brain.tiff": "https://gitlab.com/scikit-image/data/-/raw/master/brain.tiff",
#     170     "data/cells3d.tif": "https://gitlab.com/scikit-image/data/-/raw/master/cells3d.tif",
#    (...)
#     181     "restoration/tests/astronaut_rl.npy": "https://gitlab.com/scikit-image/data/-/raw/master/astronaut_rl.npy",
#     182 }
#     184 legacy_registry = {
# --> 185     ('data/' + filename): registry['data/' + filename]
#     186     for filename in legacy_datasets
#     187 }
#
# KeyError: 'data/Carneroja'

# %%
import os
print(os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/"))
import cv2
import re
import random
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, load_img
from keras import layers, models, optimizers
from keras import backend as K
from sklearn.model_selection import train_test_split
img_width = 150
img_height = 150
TRAIN_DIR = '..C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_01, CLASS_02,  CLASS_03,  CLASS_04,  CLASS_05,  CLASS_06,  CLASS_07,  CLASS_08'
TEST_DIR = '..C:/Users/botnet/Downloads/Homework/CarneDataset/test/CLASS_01, CLASS_02,  CLASS_03,  CLASS_04,  CLASS_05,  CLASS_06,  CLASS_07,  CLASS_08'
#"C:\Users\botnet\Downloads\Homework\CarneDataset\test\CLASS_01"
train_images_carne_pollo = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)] # use this for full dataset
test_images_carne_pollo = [TEST_DIR+i for i in os.listdir(TEST_DIR)]
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]
train_images_carne_pollo.sort(key=natural_keys)
train_images_carne_pollo = train_images_carne_pollo[0:13000] + train_images_carne_pollo[13500:23800] 

test_images_carne_pollo.sort(key=natural_keys)
def prepare_data(list_of_images):
    """
    Returns two arrays: 
        x is an array of resized images
        y is an array of labels
    """
    x = [] # images as arrays
    y = [] # labels
    
    for image in list_of_images:
        x.append(cv2.resize(cv2.imread(image), (img_width,img_height), interpolation=cv2.INTER_CUBIC))
    
    for i in list_of_images:
        if 'carne' in i:
            y.append(1)
        elif 'pollo' in i:
            y.append(0)
        #else:
            #print('neither cat nor dog name present in images')
            
    return x, y

X, Y = prepare_data(train_images_carne_pollo)
print(K.image_data_format())
# First split the data in two sets, 80% for training, 20% for Val/Test)
X_train, X_val, Y_train, Y_val = train_test_split(X,Y, test_size=0.2, random_state=1)

nb_train_samples = len(X_train)
nb_validation_samples = len(X_val)
batch_size = 16
# Out:
# ['test', 'train', '__MACOSX']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 8>()
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from keras.preprocessing.image import ImageDataGenerator
#       9 from keras.preprocessing.image import img_to_array, load_img
#      10 from keras import layers, models, optimizers
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import os
print(os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/test"))

# %%
import os

train_dir_content = os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02")

print("Number of Classes :", len(train_dir_content))
print(train_dir_content)

# %%
import os

train_dir_content = os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02")

print("Number of Classes :", len(train_dir_content))

current_class_name = train_dir_content[0]
class_dir = os.path.join("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02", current_class_name)
images_in_class = os.listdir(class_dir)

print("Number of Samples in Class Named", current_class_name, ":" , len(images_in_class))
# Out:
# Number of Classes : 63
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Input In [30], in <cell line: 9>()
#       7 current_class_name = train_dir_content[0]
#       8 class_dir = os.path.join("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02", current_class_name)
# ----> 9 images_in_class = os.listdir(class_dir)
#      11 print("Number of Samples in Class Named", current_class_name, ":" , len(images_in_class))
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02\\05-CAPTURE_20220421_053523_498.png'

# %%
import numpy
import keras
import matplotlib.pyplot
import os

train_dir_content = os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02")

print("Number of Classes :", len(train_dir_content))

current_class_name = train_dir_content[0]
class_dir = os.path.join("C:/Users/botnet/Downloads/Homework/CarneDataset/train/CLASS_02", current_class_name)
images_in_class = os.listdir(class_dir)

print("Number of Samples in Class Named", current_class_name, ":" , len(images_in_class))

print("Number of Samples in Class Named", current_class_name, ":" , len(images_in_class))

image_file_dir = os.path.join(class_dir, images_in_class[0])

print("Image Directory:", image_file_dir)

img = keras.preprocessing.image.load_img(image_file_dir)
img_array = keras.preprocessing.image.img_to_array(img)

print(img_array.shape, img_array.dtype)

img_array = img_array/255.0

matplotlib.pyplot.imshow(img_array)
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 import numpy
# ----> 2 import keras
#       3 import matplotlib.pyplot
#       4 import os
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import numpy
import keras
import os
import tensorflow as tf
from tensorflow.python import tf2
from keras import distribute


train_dir_content = os.listdir("C:/Users/botnet/Downloads/Homework/CarneDataset/Train")

print("Number of Classes :", len(train_dir_content))

dataset_array = []

for current_class_name in train_dir_content:

    class_dir = os.path.join("C:/Users/botnet/Downloads/Homework/CarneDataset/Train", current_class_name)
    images_in_class = os.listdir(class_dir)

    print("Number of Samples in Class Named", current_class_name, ":", len(images_in_class))

    for image_file in images_in_class:
        if image_file.endswith(".jpg"):
            image_file_dir = os.path.join(class_dir, image_file)

            img = keras.preprocessing.image.load_img(image_file_dir)
            img_array = keras.preprocessing.image.img_to_array(img)

            img_array = img_array / 255.0
            dataset_array.append(img_array)

dataset_array = numpy.array(dataset_array)
print("Training Data Array Shape :", dataset_array.shape)
